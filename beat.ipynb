# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("C:\\Users\\hp\\Downloads\\FIR_Details_Data.csv")
df.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7392\1830483871.py:1: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\hp\\Downloads\\FIR_Details_Data.csv")
#   District_Name    UnitName      FIRNo  RI  Year  Month  \
# 0      Bagalkot  Amengad PS  0001/2016   1  2016      1
# 1      Bagalkot  Amengad PS  0002/2016   1  2016      1
# 2      Bagalkot  Amengad PS  0003/2016   1  2016      1
# 3      Bagalkot  Amengad PS  0004/2016   1  2016      1
# 4      Bagalkot  Amengad PS  0005/2016   1  2016      1
#
#          Offence_From_Date          Offence_To_Date         FIR_Reg_DateTime  \
# 0  2015-12-27 12:00:00.000  2015-12-27 12:05:00.000  2016-01-05 11:00:00.000
# 1  2016-01-12 17:30:00.000  2016-01-12 17:35:00.000  2016-01-12 19:00:00.000
# 2  2016-01-12 17:45:00.000  2016-01-12 17:50:00.000  2016-01-12 19:30:00.000
# 3  2016-01-14 21:30:00.000  2016-01-14 21:35:00.000  2016-01-15 14:00:00.000
# ...

# %%
df.shape
# Out:
# (1694191, 41)

# %%
df.columns
# Out:
# Index(['District_Name', 'UnitName', 'FIRNo', 'RI', 'Year', 'Month',
#        'Offence_From_Date', 'Offence_To_Date', 'FIR_Reg_DateTime', 'FIR_Date',
#        'FIR Type', 'FIR_Stage', 'Complaint_Mode', 'CrimeGroup_Name',
#        'CrimeHead_Name', 'Latitude', 'Longitude', 'ActSection', 'IOName',
#        'KGID', 'IOAssigned_Date', 'Internal_IO', 'Place of Offence',
#        'Distance from PS', 'Beat_Name', 'Village_Area_Name', 'Male', 'Female',
#        'Boy', 'Girl', 'Age 0', 'VICTIM COUNT', 'Accused Count',
#        'Arrested Male', 'Arrested Female', 'Arrested Count\tNo.',
#        'Accused_ChargeSheeted Count', 'Conviction Count', 'FIR_ID', 'Unit_ID',
#        'Crime_No'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of         District_Name          UnitName      FIRNo  RI  Year  Month  \
# 0            Bagalkot        Amengad PS  0001/2016   1  2016      1
# 1            Bagalkot        Amengad PS  0002/2016   1  2016      1
# 2            Bagalkot        Amengad PS  0003/2016   1  2016      1
# 3            Bagalkot        Amengad PS  0004/2016   1  2016      1
# 4            Bagalkot        Amengad PS  0005/2016   1  2016      1
# ...               ...               ...        ...  ..   ...    ...
# 1694186        Yadgir  Yadgiri Women PS  0002/2024   1  2024      1
# 1694187        Yadgir  Yadgiri Women PS  0003/2024   1  2024      1
# 1694188        Yadgir  Yadgiri Women PS  0004/2024   1  2024      2
# 1694189        Yadgir  Yadgiri Women PS  0005/2024   1  2024      2
# 1694190        Yadgir  Yadgiri Women PS  0006/2024   1  2024      2
#
#                Offence_From_Date          Offence_To_Date  \
# 0        2015-12-27 12:00:00.000  2015-12-27 12:05:00.000
# ...

# %%
df.isnull().sum()
# Out:
# District_Name                        0
# UnitName                             0
# FIRNo                                0
# RI                                   0
# Year                                 0
# Month                                0
# Offence_From_Date                    0
# Offence_To_Date                      1
# FIR_Reg_DateTime                     0
# FIR_Date                             0
# FIR Type                             2
# FIR_Stage                            0
# Complaint_Mode                   18430
# CrimeGroup_Name                      0
# CrimeHead_Name                       0
# Latitude                             5
# Longitude                            5
# ActSection                          42
# IOName                             150
# KGID                               150
# IOAssigned_Date                1694182
# Internal_IO                          0
# Place of Offence                     0
# Distance from PS                   567
# ...

# %%
df.dropna()
# Out:
#           District_Name                 UnitName      FIRNo  RI  Year  Month  \
# 74913     Belagavi City                Market PS  0120/2023   1  2023      7
# 357564   Bengaluru City    Kempapura Agrahara PS  0134/2022   1  2022      8
# 703613   Chickballapura  Chickballapura Rural PS  0028/2024   1  2024      2
# 705006   Chickballapura   Chickballapura Town PS  0095/2023   1  2023      7
# 1196732          Mandya                Maddur PS  0257/2023   1  2023      8
# 1284261     Mysuru City     V V Puram Traffic PS  0190/2018   1  2018     10
# 1284319     Mysuru City     V V Puram Traffic PS  0011/2019   1  2019      1
# 1528957        Tumakuru                  Sira PS  0180/2023   1  2023      6
# 1537615        Tumakuru        Tumakuru Rural PS  0223/2023   1  2023      8
#
#                Offence_From_Date          Offence_To_Date  \
# 74913    2023-05-03 15:30:00.000  2023-05-03 17:30:00.000
# 357564   2022-08-12 22:00:00.000  2022-08-13 00:45:00.000
# ...

# %%
df['CrimeGroup_Name'] = df['CrimeGroup_Name'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1694191 entries, 0 to 1694190
# Data columns (total 41 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   District_Name                object
#  1   UnitName                     object
#  2   FIRNo                        object
#  3   RI                           int64
#  4   Year                         int64
#  5   Month                        int64
#  6   Offence_From_Date            object
#  7   Offence_To_Date              object
#  8   FIR_Reg_DateTime             object
#  9   FIR_Date                     object
#  10  FIR Type                     object
#  11  FIR_Stage                    object
#  12  Complaint_Mode               object
#  13  CrimeGroup_Name              object
#  14  CrimeHead_Name               object
#  15  Latitude                     float64
#  16  Longitude                    float64
#  17  ActSection                   object
# ...

# %%
string_columns = df.select_dtypes(include=['object']).columns.tolist()
string_columns
# Out:
# ['District_Name',
#  'UnitName',
#  'FIRNo',
#  'Offence_From_Date',
#  'Offence_To_Date',
#  'FIR_Reg_DateTime',
#  'FIR_Date',
#  'FIR Type',
#  'FIR_Stage',
#  'Complaint_Mode',
#  'CrimeGroup_Name',
#  'CrimeHead_Name',
#  'ActSection',
#  'IOName',
#  'KGID',
#  'IOAssigned_Date',
#  'Place of Offence',
#  'Distance from PS',
#  'Beat_Name',
#  'Village_Area_Name']

# %%
enc = LabelEncoder()

for i in string_columns:
    df[i] = df[i].astype(str)
    df[i] = enc.fit_transform(df[i])
df.head()
# Out:
#    District_Name  UnitName  FIRNo  RI  Year  Month  Offence_From_Date  \
# 0              0        26      0   1  2016      1              19614
# 1              0        26      9   1  2016      1              21598
# 2              0        26     18   1  2016      1              21600
# 3              0        26     27   1  2016      1              21887
# 4              0        26     36   1  2016      1              22374
#
#    Offence_To_Date  FIR_Reg_DateTime  FIR_Date  ...  VICTIM COUNT  \
# 0             9263               491       396  ...             0
# 1            12320              1338      1088  ...             0
# 2            12324              1341      1088  ...             0
# 3            12829              1652      1382  ...             0
# 4            13649              2025      1676  ...             0
#
#    Accused Count  Arrested Male  Arrested Female  Arrested Count\tNo.  \
# 0              1              1                0                    1
# ...

# %%
df.corr()
# Out:
#                              District_Name  UnitName     FIRNo  RI      Year  \
# District_Name                     1.000000  0.133658 -0.191262 NaN -0.023647
# UnitName                          0.133658  1.000000 -0.018154 NaN  0.006246
# FIRNo                            -0.191262 -0.018154  1.000000 NaN -0.050674
# RI                                     NaN       NaN       NaN NaN       NaN
# Year                             -0.023647  0.006246 -0.050674 NaN  1.000000
# Month                            -0.020864 -0.000037  0.395494 NaN -0.022509
# Offence_From_Date                -0.016787  0.005978  0.002093 NaN  0.954757
# Offence_To_Date                  -0.025517  0.005347 -0.000852 NaN  0.984086
# FIR_Reg_DateTime                 -0.025601  0.005630 -0.001155 NaN  0.992398
# FIR_Date                         -0.005221 -0.000501  0.045651 NaN  0.001447
# FIR Type                         -0.030747  0.003021  0.016817 NaN -0.008292
# ...

# %%
df_clean_rows = df.dropna()

# %%
df_clean_columns = df.dropna(axis=1)

# %%
df
# Out:
#          District_Name  UnitName  FIRNo  Year  Month  Offence_From_Date  \
# 0                    0        26      0  2016      1              19614
# 1                    0        26      9  2016      1              21598
# 2                    0        26     18  2016      1              21600
# 3                    0        26     27  2016      1              21887
# 4                    0        26     36  2016      1              22374
# ...                ...       ...    ...   ...    ...                ...
# 1694186             40      1038     17  2024      1             433115
# 1694187             40      1038     26  2024      1             434559
# 1694188             40      1038     35  2024      2             437087
# 1694189             40      1038     44  2024      2             438967
# 1694190             40      1038     53  2024      2             440081
#
#          Offence_To_Date  FIR_Reg_DateTime  FIR_Date  FIR Type  ...  \
# ...

# %%
df.columns
# Out:
# Index(['District_Name', 'UnitName', 'FIRNo', 'Year', 'Month',
#        'Offence_From_Date', 'Offence_To_Date', 'FIR_Reg_DateTime', 'FIR_Date',
#        'FIR Type', 'FIR_Stage', 'Complaint_Mode', 'CrimeGroup_Name',
#        'CrimeHead_Name', 'Latitude', 'Longitude', 'ActSection', 'IOName',
#        'KGID', 'IOAssigned_Date', 'Internal_IO', 'Place of Offence',
#        'Distance from PS', 'Beat_Name', 'Village_Area_Name', 'Male', 'Female',
#        'Boy', 'Girl', 'Age 0', 'VICTIM COUNT', 'Accused Count',
#        'Arrested Male', 'Arrested Female', 'Arrested Count\tNo.',
#        'Accused_ChargeSheeted Count', 'Conviction Count', 'FIR_ID', 'Unit_ID',
#        'Crime_No'],
#       dtype='object')

# %%
print(df['Beat_Name'].unique())
# Out:
# [5533 5545 5536 ... 2219 6701 6642]

# %%
print(df['VICTIM COUNT'].unique())
# Out:
# [ 0  1  8 16  2  3  6  5  4]

# %%
print(df['Accused_ChargeSheeted Count'].unique())
# Out:
# [  1   5   2   8  34  13  19  12   7  11  16   0   6   4  10   3   9  20
#   15  24  14  21  23  17  25  22  39  26  18  31  28  27  29  49  36  44
#   37  45  32  40  42  56  41  43  57  46  48  38  53  68  35  30  52  67
#   33  51  79 116  58  74  55  65  50  77  69  64  54  85  59  72 196 293
#   75  47 124  71 100 109  61 128  82  73  60  81  66  86 203 143  92  63
#  160  70  89  98 105  78 102  87  80 155 107 115 139  84  94  90 154 330
#   97  93 111  95 131  62 101 167  76 110 103 108 104  83 117  91 106 130
#  133]

# %%
print(df['Conviction Count'].unique())
# Out:
# [ 0  2  1  9  4  5 11 15  7 10  8  3  6 12 19 13 14 18 16 21 20 40 24 28
#  17 23 22 38 26 32 41 37 58 33 35 36 27 50 29 39 31 25 30 43 34 49 42 44
#  74 45]

# %%
df = df.rename(columns={'Conviction Count': 'ConvictionCount'})

# %%
Y = df.ConvictionCount
X = df.iloc[:,[3,4,5,6,12,13,14,15,17,21,3,32,35,36]] 
X.head()
# Out:
#    Year  Month  Offence_From_Date  Offence_To_Date  CrimeGroup_Name  \
# 0  2016      1              19614             9263               86
# 1  2016      1              21598            12320               66
# 2  2016      1              21600            12324               66
# 3  2016      1              21887            12829               73
# 4  2016      1              22374            13649               72
#
#    CrimeHead_Name  Latitude  Longitude  IOName  Place of Offence  Year  \
# 0             351       0.0        0.0   15172            537660  2016
# 1             437       0.0        0.0    4649           1113786  2016
# 2             178       0.0        0.0   17622           1113770  2016
# 3             285       0.0        0.0   15172            118514  2016
# 4             350       0.0        0.0    8522             44940  2016
#
#    Arrested Male  Accused_ChargeSheeted Count  ConvictionCount
# 0              1                            1                0
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=10)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model_logr = LogisticRegression()
model_logr.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [97], in <cell line: 3>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 model_logr = LogisticRegression()
# ----> 3 model_logr.fit(X_train,Y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1508, in LogisticRegression.fit(self, X, y, sample_weight)
#    1505 else:
#    1506     _dtype = [np.float64, np.float32]
# -> 1508 X, y = self._validate_data(
#    1509     X,
#    1510     y,
#    1511     accept_sparse="csr",
#    1512     dtype=_dtype,
#    1513     order="C",
#    1514     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515 )
#    1516 check_classification_targets(y)
#    1517 self.classes_ = np.unique(y)
#
# ...
